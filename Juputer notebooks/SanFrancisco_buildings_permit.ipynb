# %% [markdown]
# # San Francisco Building Permits
#
# >5 years and 200k building permits
#
# ![costar-transamerica.jpg](attachment:costar-transamerica.jpg)
#
#
# ### Introduction
#
# >A building permit is an official approval document issued by a government agency that allows you or your contractor to proceed with a construction for remodeling project on one's property. Each city or country has its own officerelated to buildings, that can do multiple functions like issuing permits, inspecting buildings to enforce safety measures, modifying rules to accommodate needs of the growing population and so on. For the city of San Francisco, permit issuing is taken care by San Francisco government.
#
# > This dataset related to building permits is downloaded from kaggle. There are some certain features of the dataset which are given below :-
# >>* The data getting updated by San Francisco Open Data portal every Saturday.
# >>* There are 43 columns with 1,98,900 rows wuth we can do different sort of things according one's own creativity.
# >>* The data's column described in codes which are explained in different excel file which to access.
# >>* Address is divided in different parts from block to street name suffix which make it easy to get information through it.
# >>* Supervisor District and permit are assigned in form of numerical data that makes for both us and python to go through easily then check by another excel sheet about designated value.
# >>* Dates for every stage is given such as filed, issued, completed and expiration date.

# %% [markdown]
# ## Downloading and Importing the Dataset
#
# ### 1. Downloading Dataset
# >There are saveral ways through which we can download the datasets from particular website such as by using **urlretrieve library** or by **opendatasets library** but as I have manually downloaded my dataset from link that is given below, I am going to directlyimport the dataset by using **pandas**.
#
# link:- https://www.kaggle.com/datasets/aparnashastry/building-permit-applications-data

# %%
import os #to know the files that are downloaded

# %%
os.listdir('building dataset')
# Out:
# ['Building_Permits.csv', 'DataDictionaryBuildingPermit.xlsx']

# %% [markdown]
# > * DataDictionaryBuildingPermit.xlsx - The list of shortcodes for each column main dataset.
# > * Building_permits.csv - The full information about building permits according to their ids.

# %% [markdown]
# ### 2. Importing Dataset
#
# > Now, I will import csv file and xlsx file by **Pandas** for better tabular visualization then I take out columns from the pandas data frame then limit our field of analysis to certain range of data provided.

# %%
import pandas as pd #to import dataset in tabular form and clean it
import numpy as np #to do the complex calculations

# %%
building_raw_df = pd.read_csv('building dataset/Building_Permits.csv')
# Out:
# C:\Users\ABC\AppData\Local\Temp\ipykernel_3764\828121404.py:1: DtypeWarning: Columns (22,32) have mixed types. Specify dtype option on import or set low_memory=False.
#   building_raw_df = pd.read_csv('building dataset/Building_Permits.csv')

# %%
building_raw_df
# Out:
#        Permit Number  Permit Type            Permit Type Definition  \
# 0       201505065519            4                      sign - erect
# 1       201604195146            4                      sign - erect
# 2       201605278609            3  additions alterations or repairs
# 3       201611072166            8            otc alterations permit
# 4       201611283529            6                       demolitions
# ...              ...          ...                               ...
# 198895       M862628            8            otc alterations permit
# 198896  201712055595            8            otc alterations permit
# 198897       M863507            8            otc alterations permit
# 198898       M863747            8            otc alterations permit
# 198899       M864287            8            otc alterations permit
#
#        Permit Creation Date Block   Lot  Street Number Street Number Suffix  \
# 0                05/06/2015  0326   023            140                  NaN
# 1                04/19/2016  0306   007            440                  NaN
# 2                05/27/2016  0595   203           1647                  NaN
# 3                11/07/2016  0156   011           1230                  NaN
# 4                11/28/2016  0342   001            950                  NaN
# ...                     ...   ...   ...            ...                  ...
# 198895           12/05/2017  0113  017A           1228                  NaN
# 198896           12/05/2017  0271   014            580                  NaN
# 198897           12/06/2017  4318   019           1568                  NaN
# 198898           12/06/2017  0298   029            795                  NaN
# 198899           12/07/2017  0160   006            838                  NaN
#
#        Street Name Street Suffix  ...  Existing Construction Type  \
# 0            Ellis            St  ...                         3.0
# 1            Geary            St  ...                         3.0
# 2          Pacific            Av  ...                         1.0
# 3          Pacific            Av  ...                         5.0
# 4           Market            St  ...                         3.0
# ...            ...           ...  ...                         ...
# 198895  Montgomery            St  ...                         NaN
# 198896        Bush            St  ...                         5.0
# 198897     Indiana            St  ...                         NaN
# 198898      Sutter            St  ...                         NaN
# 198899     Pacific            Av  ...                         NaN
#
#        Existing Construction Type Description Proposed Construction Type  \
# 0                               constr type 3                        NaN
# 1                               constr type 3                        NaN
# 2                               constr type 1                        1.0
# 3                              wood frame (5)                        5.0
# 4                               constr type 3                        NaN
# ...                                       ...                        ...
# 198895                                    NaN                        NaN
# 198896                         wood frame (5)                        5.0
# 198897                                    NaN                        NaN
# 198898                                    NaN                        NaN
# 198899                                    NaN                        NaN
#
#        Proposed Construction Type Description Site Permit Supervisor District  \
# 0                                         NaN         NaN                 3.0
# 1                                         NaN         NaN                 3.0
# 2                               constr type 1         NaN                 3.0
# 3                              wood frame (5)         NaN                 3.0
# 4                                         NaN         NaN                 6.0
# ...                                       ...         ...                 ...
# 198895                                    NaN         NaN                 NaN
# 198896                         wood frame (5)         NaN                 NaN
# 198897                                    NaN         NaN                 NaN
# 198898                                    NaN         NaN                 NaN
# 198899                                    NaN         NaN                 NaN
#
#        Neighborhoods - Analysis Boundaries  Zipcode  \
# 0                               Tenderloin  94102.0
# 1                               Tenderloin  94102.0
# 2                             Russian Hill  94109.0
# 3                                 Nob Hill  94109.0
# 4                               Tenderloin  94102.0
# ...                                    ...      ...
# 198895                                 NaN      NaN
# 198896                                 NaN      NaN
# 198897                                 NaN      NaN
# 198898                                 NaN      NaN
# 198899                                 NaN      NaN
#
#                                          Location      Record ID
# 0       (37.785719256680785, -122.40852313194863)  1380611233945
# 1        (37.78733980600732, -122.41063199757738)  1420164406718
# 2         (37.7946573324287, -122.42232562979227)  1424856504716
# 3        (37.79595867909168, -122.41557405519474)  1443574295566
# 4        (37.78315261897309, -122.40950883997789)   144548169992
# ...                                           ...            ...
# 198895                                        NaN  1489337276729
# 198896                                        NaN  1489462354993
# 198897                                        NaN  1489539379952
# 198898                                        NaN  1489608233656
# 198899                                        NaN  1489796283803
#
# [198900 rows x 43 columns]

# %%
building_raw_df.columns
# Out:
# Index(['Permit Number', 'Permit Type', 'Permit Type Definition',
#        'Permit Creation Date', 'Block', 'Lot', 'Street Number',
#        'Street Number Suffix', 'Street Name', 'Street Suffix', 'Unit',
#        'Unit Suffix', 'Description', 'Current Status', 'Current Status Date',
#        'Filed Date', 'Issued Date', 'Completed Date',
#        'First Construction Document Date', 'Structural Notification',
#        'Number of Existing Stories', 'Number of Proposed Stories',
#        'Voluntary Soft-Story Retrofit', 'Fire Only Permit',
#        'Permit Expiration Date', 'Estimated Cost', 'Revised Cost',
#        'Existing Use', 'Existing Units', 'Proposed Use', 'Proposed Units',
#        'Plansets', 'TIDF Compliance', 'Existing Construction Type',
#        'Existing Construction Type Description', 'Proposed Construction Type',
#        'Proposed Construction Type Description', 'Site Permit',
#        'Supervisor District', 'Neighborhoods - Analysis Boundaries', 'Zipcode',
#        'Location', 'Record ID'],
#       dtype='object')

# %% [markdown]
# >Now, let's get the overview of dataset that I have just imported and check the columns that I can work with efficiently. Firstly, load the other dataset that is giving information about the columns of main data.

# %%
data_dictionary_df = pd.read_excel('building dataset/DataDictionaryBuildingPermit.xlsx',index_col='Sl No')

# %%
data_dictionary_df
# Out:
#                                   Column name  \
# Sl No
# 1.0                             Permit Number
# 2.0                               Permit Type
# 3.0                    Permit Type Definition
# 4.0                      Permit Creation Date
# 5.0                                     Block
# 6.0                                       Lot
# 7.0                             Street Number
# 8.0                      Street Number Suffix
# 9.0                               Street Name
# 10.0                       Street Name Suffix
# 11.0                                     Unit
# 12.0                              Unit suffix
# 13.0                              Description
# 14.0                           Current Status
# 15.0                      Current Status Date
# 16.0                               Filed Date
# 17.0                              Issued Date
# 18.0                           Completed Date
# 19.0         First Construction Document Date
# 20.0                  Structural Notification
# 21.0               Number of Existing Stories
# 22.0               Number of Proposed Stories
# 23.0          Voluntary Soft-Story \nRetrofit
# 24.0                         Fire Only Permit
# 25.0                   Permit Expiration Date
# 26.0                           Estimated Cost
# 27.0                             Revised Cost
# 28.0                             Existing Use
# 29.0                           Existing Units
# 30.0                             Proposed Use
# 31.0                           Proposed Units
# 32.0                                 Plansets
# 33.0                          TIDF Compliance
# 34.0               Existing Construction Type
# 35.0   Existing Construction Type Description
# 36.0               Proposed Construction Type
# 37.0   Proposed Construction Type Description
# 38.0                              Site Permit
# 39.0                      Supervisor District
# 40.0      Neighborhoods - Analysis Boundaries
# 41.0                                  Zipcode
# 42.0                                 Location
# 43.0                                Record ID
#
#                                              Description
# Sl No
# 1.0                         Number assigned while filing
# 2.0          Type of the permit represented numerically.
# 3.0    Description of the Permit type, for example\n ...
# 4.0    Date on which permit created, later than \nor ...
# 5.0                                   Related to address
# 6.0                                   Related to address
# 7.0                                   Related to address
# 8.0                                   Related to address
# 9.0                                   Related to address
# 10.0                                  Related to address
# 11.0                                  Unit of a building
# 12.0                         Suffix if any, for the unit
# 13.0   Details about purpose of the permit.\n Example...
# 14.0          Current status of the permit application.
# 15.0            Date at which current status was entered
# 16.0                           Filed date for the permit
# 17.0                          Issued date for the permit
# 18.0   The date on which project was completed, \napp...
# 19.0           Date on which construction was documented
# 20.0   Notification to meet some legal need, given or...
# 21.0   Number of existing stories in the building. \n...
# 22.0   Number of proposed stories for the constructio...
# 23.0          Soft story to meet earth quake regulations
# 24.0               Fire hazard prevention related permit
# 25.0           Expiration date related to issued permit.
# 26.0       Initial estimation of the cost of the project
# 27.0       Revised estimation of the cost of the project
# 28.0                        Existing use of the building
# 29.0                            Existing number of units
# 30.0                        Proposed use of the building
# 31.0                            Proposed number of units
# 32.0   Plan representation indicating the general des...
# 33.0   TIDF compliant or not, this is a new legal req...
# 34.0   Construction type, existing,as categories \nre...
# 35.0   Description of the above, for example, \nwood ...
# 36.0   Construction type, proposed, as categories\n r...
# 37.0                            Description of the above
# 38.0                                     Permit for site
# 39.0   Supervisor District to which the building loca...
# 40.0   Neighborhood to which the building location be...
# 41.0                         Zipcode of building address
# 42.0               Location in latitude, longitude pair.
# 43.0                        Some ID, not useful for this

# %% [markdown]
# >As I have imported the dataset and get the information about the columns that they provide. Now, I am going to select the columns which I am going to use in our further section.

# %% [markdown]
# ## Data Preparation and Cleaning

# %% [markdown]
# >Now, firstly I am going to limit our view over some certain fields to get the best information out of this dataset.

# %%
selected_columns = ['Permit Type',
                    'Permit Type Definition',
                   'Permit Creation Date',
                   'Street Name',
                   'Street Suffix',
                   'Description',
                   'Filed Date',
                   'Issued Date',
                    'Permit Expiration Date',
                   'Estimated Cost',
                   'Revised Cost',
                   'Existing Construction Type',
                   'Existing Construction Type Description',
                   'Proposed Construction Type',
                   'Proposed Construction Type Description',
                   'Supervisor District']

# %%
len(selected_columns)
# Out:
# 16

# %% [markdown]
# >I have selected **16 columns** to limits my area of analysis and get the useful information that I think I can extract from the given information.
#
# >I will now extract a copy of the data from these columns into a new data frame **building_df**. Hence, data can be modified further without having affect on original dataset.

# %%
building_df = building_raw_df[selected_columns].copy()
building_df
# Out:
#         Permit Type            Permit Type Definition Permit Creation Date  \
# 0                 4                      sign - erect           05/06/2015
# 1                 4                      sign - erect           04/19/2016
# 2                 3  additions alterations or repairs           05/27/2016
# 3                 8            otc alterations permit           11/07/2016
# 4                 6                       demolitions           11/28/2016
# ...             ...                               ...                  ...
# 198895            8            otc alterations permit           12/05/2017
# 198896            8            otc alterations permit           12/05/2017
# 198897            8            otc alterations permit           12/06/2017
# 198898            8            otc alterations permit           12/06/2017
# 198899            8            otc alterations permit           12/07/2017
#
#        Street Name Street Suffix  \
# 0            Ellis            St
# 1            Geary            St
# 2          Pacific            Av
# 3          Pacific            Av
# 4           Market            St
# ...            ...           ...
# 198895  Montgomery            St
# 198896        Bush            St
# 198897     Indiana            St
# 198898      Sutter            St
# 198899     Pacific            Av
#
#                                               Description  Filed Date  \
# 0       ground fl facade: to erect illuminated, electr...  05/06/2015
# 1                 remove (e) awning and associated signs.  04/19/2016
# 2                         installation of separating wall  05/27/2016
# 3                repair dryrot & stucco at front of bldg.  11/07/2016
# 4       demolish retail/office/commercial 3-story buil...  11/28/2016
# ...                                                   ...         ...
# 198895                                       street space  12/05/2017
# 198896                fire alarm upgrade ref 201704123852  12/05/2017
# 198897                                       street space  12/06/2017
# 198898                                street space permit  12/06/2017
# 198899                                street space permit  12/07/2017
#
#        Issued Date Permit Expiration Date  Estimated Cost  Revised Cost  \
# 0       11/09/2015             11/03/2016          4000.0        4000.0
# 1       08/03/2017             12/03/2017             1.0         500.0
# 2              NaN                    NaN         20000.0           NaN
# 3       07/18/2017             07/13/2018          2000.0        2000.0
# 4       12/01/2017             12/01/2018        100000.0      100000.0
# ...            ...                    ...             ...           ...
# 198895  12/05/2017                    NaN             NaN           1.0
# 198896  12/06/2017             04/06/2018          5000.0        5000.0
# 198897  12/06/2017                    NaN             NaN           1.0
# 198898  12/06/2017                    NaN             NaN           1.0
# 198899  12/07/2017                    NaN             NaN           1.0
#
#         Existing Construction Type Existing Construction Type Description  \
# 0                              3.0                          constr type 3
# 1                              3.0                          constr type 3
# 2                              1.0                          constr type 1
# 3                              5.0                         wood frame (5)
# 4                              3.0                          constr type 3
# ...                            ...                                    ...
# 198895                         NaN                                    NaN
# 198896                         5.0                         wood frame (5)
# 198897                         NaN                                    NaN
# 198898                         NaN                                    NaN
# 198899                         NaN                                    NaN
#
#         Proposed Construction Type Proposed Construction Type Description  \
# 0                              NaN                                    NaN
# 1                              NaN                                    NaN
# 2                              1.0                          constr type 1
# 3                              5.0                         wood frame (5)
# 4                              NaN                                    NaN
# ...                            ...                                    ...
# 198895                         NaN                                    NaN
# 198896                         5.0                         wood frame (5)
# 198897                         NaN                                    NaN
# 198898                         NaN                                    NaN
# 198899                         NaN                                    NaN
#
#         Supervisor District
# 0                       3.0
# 1                       3.0
# 2                       3.0
# 3                       3.0
# 4                       6.0
# ...                     ...
# 198895                  NaN
# 198896                  NaN
# 198897                  NaN
# 198898                  NaN
# 198899                  NaN
#
# [198900 rows x 16 columns]

# %% [markdown]
# > Now, as we have selected the the columns from which we are going to extract information. So, let's get started with the description.

# %%
building_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 198900 entries, 0 to 198899
# Data columns (total 16 columns):
#  #   Column                                  Non-Null Count   Dtype
# ---  ------                                  --------------   -----
#  0   Permit Type                             198900 non-null  int64
#  1   Permit Type Definition                  198900 non-null  object
#  2   Permit Creation Date                    198900 non-null  object
#  3   Street Name                             198900 non-null  object
#  4   Street Suffix                           196132 non-null  object
#  5   Description                             198610 non-null  object
#  6   Filed Date                              198900 non-null  object
#  7   Issued Date                             183960 non-null  object
#  8   Permit Expiration Date                  147020 non-null  object
#  9   Estimated Cost                          160834 non-null  float64
#  10  Revised Cost                            192834 non-null  float64
#  11  Existing Construction Type              155534 non-null  float64
#  12  Existing Construction Type Description  155534 non-null  object
#  13  Proposed Construction Type              155738 non-null  float64
#  14  Proposed Construction Type Description  155738 non-null  object
#  15  Supervisor District                     197183 non-null  float64
# dtypes: float64(5), int64(1), object(10)
# memory usage: 16.7+ MB

# %% [markdown]
# >Most of the columns have data type object, either because they contain values of differenttypes or empty values(Nan). It appears that every column contains some empty values since the Non-Null count for every column is lower than total number of rows(198,900).
#
# > But if we analyze the the columns there are some information that is provided in non-numerical way and hence, it is in object datatype. And rest of the columns that have numeric values are in float or integer data types. Hence, there is no need to manually change the non-numeric values to Nan because it is already done in data set and thats the reason inspite less non-null values than the total number of rows, these columns have float or int datatype.

# %%
missing_value_count = building_df.isnull().sum()
missing_value_count

total_cells = np.product(building_df.shape)
total_missing = missing_value_count.sum()

percent_missing = (total_missing/total_cells)*100
print(percent_missing)
# Out:
# 9.074377828054299

# %% [markdown]
# >Above, I have just checked the number of null values that are pesent in the data set and there are around 9%.

# %%
building_df.describe()
# Out:
#          Permit Type  Estimated Cost  Revised Cost  \
# count  198900.000000    1.608340e+05  1.928340e+05
# mean        7.522323    1.689554e+05  1.328562e+05
# std         1.457451    3.630386e+06  3.584903e+06
# min         1.000000    1.000000e+00  0.000000e+00
# 25%         8.000000    3.300000e+03  1.000000e+00
# 50%         8.000000    1.100000e+04  7.000000e+03
# 75%         8.000000    3.500000e+04  2.870750e+04
# max         8.000000    5.379586e+08  7.805000e+08
#
#        Existing Construction Type  Proposed Construction Type  \
# count               155534.000000               155738.000000
# mean                     4.072878                    4.089529
# std                      1.585756                    1.578766
# min                      1.000000                    1.000000
# 25%                      3.000000                    3.000000
# 50%                      5.000000                    5.000000
# 75%                      5.000000                    5.000000
# max                      5.000000                    5.000000
#
#        Supervisor District
# count        197183.000000
# mean              5.538403
# std               2.887041
# min               1.000000
# 25%               3.000000
# 50%               6.000000
# 75%               8.000000
# max              11.000000

# %% [markdown]
# >There seems to be a problem with the **Estimated Cost** and **Revised Cost** , as the minimum estimated cost is 1.0 while, minimum revised cost is 0.0 and 25% rows have 1.0 revised cost. We will simple fix it by ignoring the rows that hold this value by using **.drop** function.

# %%
building_df.drop(building_df[building_df['Estimated Cost'] <10].index, inplace=True)
building_df.drop(building_df[building_df['Revised Cost'] <10].index, inplace=True)

# %% [markdown]
# >As, we I have simply removed the values from the selected column that does not fit right in the dataset in accordance with others.

# %%
building_df['Street Suffix'].value_counts()
# Out:
# St    95725
# Av    32343
# Wy     2731
# Bl     2726
# Dr     2724
# Tr     1053
# Ct      560
# Pl      391
# Rd      307
# Ln      288
# Hy      187
# Pz      157
# Pk       96
# Cr       80
# Al       58
# Wk        4
# Rw        3
# So        2
# No        2
# Sw        1
# Hl        1
# Name: Street Suffix, dtype: int64

# %% [markdown]
# >In the above line of code I just checked the adress of building related to their street to ensure that they are not mixed up.
# Now, we are ready to do our analysis as there no mistake in street suffix and other data.

# %% [markdown]
# ## Exploratory Analysis and Visualization

# %% [markdown]
# >Before answering some questions lets extract some information further to understand the way information is provided.
#
# > Let's import the **matplotlib** and **seaborn** library.

# %%
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt

sns.set_style('darkgrid')

# %% [markdown]
# ### Permit Type and Permit Type Definition
#
# >Let's have a look over the permit types that are given and check which type permit is most taken by buildings.

# %%
building_df[['Permit Type','Permit Type Definition']]
# Out:
#         Permit Type            Permit Type Definition
# 0                 4                      sign - erect
# 2                 3  additions alterations or repairs
# 3                 8            otc alterations permit
# 4                 6                       demolitions
# 5                 8            otc alterations permit
# ...             ...                               ...
# 198890            3  additions alterations or repairs
# 198892            8            otc alterations permit
# 198893            8            otc alterations permit
# 198894            8            otc alterations permit
# 198896            8            otc alterations permit
#
# [141407 rows x 2 columns]

# %%
permit = building_df['Permit Type'].value_counts().head(5)
permit
# Out:
# 8    122395
# 3     13725
# 4      2871
# 2       888
# 6       599
# Name: Permit Type, dtype: int64

# %%
plt.xticks(rotation =75)
plt.title('Permit acquired by buildings')
sns.barplot(x = permit.index, y = permit );

# %% [markdown]
# >As we can clearly almost all of the buildings acquire permit type **8** which is an **otc alteration permit** followed by permit type **3** which is an **addition alterations or repairs**.

# %% [markdown]
# #### (OTC) Permit - Over The Counter Permit
# The Department of Building Inspection reviews every building permit application for life safety and building code compliance. Officials provide over-the-counter review for simple permit application. It works in 5 simple steps:-
# * Review the list on website of gonvernment to see if project qualifies for OTC review.
# * Check if any plan is needed.
# * Go through required form for certain project.
# * Follow instructions to fill out the forms for that certain project.
# * Visit Permit Center.

# %% [markdown]
# ### Perdiction made on the basis of selected data
#
# >I am going to use correlation function to know the relation between the columns of data set and try to figure out if I can make any perdiction.

# %%
building_df.corr()
# Out:
#                             Permit Type  Estimated Cost  Revised Cost  \
# Permit Type                    1.000000       -0.123945     -0.121594
# Estimated Cost                -0.123945        1.000000      0.979829
# Revised Cost                  -0.121594        0.979829      1.000000
# Existing Construction Type    -0.005608       -0.051697     -0.061429
# Proposed Construction Type    -0.038195       -0.060934     -0.052310
# Supervisor District           -0.043730        0.010588      0.007222
#
#                             Existing Construction Type  \
# Permit Type                                  -0.005608
# Estimated Cost                               -0.051697
# Revised Cost                                 -0.061429
# Existing Construction Type                    1.000000
# Proposed Construction Type                    0.999033
# Supervisor District                           0.152595
#
#                             Proposed Construction Type  Supervisor District
# Permit Type                                  -0.038195            -0.043730
# Estimated Cost                               -0.060934             0.010588
# Revised Cost                                 -0.052310             0.007222
# Existing Construction Type                    0.999033             0.152595
# Proposed Construction Type                    1.000000             0.149904
# Supervisor District                           0.149904             1.000000

# %%
sns.heatmap(building_df.corr(), linewidths = 1, annot = True)
plt.title('Correlation between the variables');

# %% [markdown]
# >From heatmap we can account that **revised cost** and **estimated cost** somehow depended on each other. Hence, with **increase** in **revised cost** would likely also **increase estimated cost** or vise-versa.
#
# >Interestingly, **Existing construction type** and **porposed construction type** entirely depend on each other.

# %% [markdown]
# ### File Issued and Expiration Date
#
# >Firstly, I will convert the the data type of dates which are object right now into datetime data type and extract information in form of graphs.

# %%
building_df['Issued Date'] = pd.to_datetime(building_df['Issued Date'])
building_df['Permit Expiration Date'] = pd.to_datetime(building_df['Permit Expiration Date'])

# %% [markdown]
# >Now, i will introduce new column from these dates in form of month and weekdays. So, that I can get the time when most of the permits issues and expires.

# %%
# For permit issued date
building_df['Issued_month'] = pd.DatetimeIndex(building_df['Issued Date']).month
building_df['Issued_weekday'] = pd.DatetimeIndex(building_df['Issued Date']).weekday
# For permit expirate date
building_df['Expiration_month'] = pd.DatetimeIndex(building_df['Permit Expiration Date']).month
building_df['Expiration_weekday'] = pd.DatetimeIndex(building_df['Permit Expiration Date']).weekday

# %%
building_df.head(5)
# Out:
#    Permit Type            Permit Type Definition Permit Creation Date  \
# 0            4                      sign - erect           05/06/2015
# 2            3  additions alterations or repairs           05/27/2016
# 3            8            otc alterations permit           11/07/2016
# 4            6                       demolitions           11/28/2016
# 5            8            otc alterations permit           06/14/2017
#
#   Street Name Street Suffix  \
# 0       Ellis            St
# 2     Pacific            Av
# 3     Pacific            Av
# 4      Market            St
# 5     Indiana            St
#
#                                          Description  Filed Date Issued Date  \
# 0  ground fl facade: to erect illuminated, electr...  05/06/2015  2015-11-09
# 2                    installation of separating wall  05/27/2016         NaT
# 3           repair dryrot & stucco at front of bldg.  11/07/2016  2017-07-18
# 4  demolish retail/office/commercial 3-story buil...  11/28/2016  2017-12-01
# 5                                          evac maps  06/14/2017  2017-07-06
#
#   Permit Expiration Date  Estimated Cost  Revised Cost  \
# 0             2016-11-03          4000.0        4000.0
# 2                    NaT         20000.0           NaN
# 3             2018-07-13          2000.0        2000.0
# 4             2018-12-01        100000.0      100000.0
# 5             2018-07-01          4000.0        4000.0
#
#    Existing Construction Type Existing Construction Type Description  \
# 0                         3.0                          constr type 3
# 2                         1.0                          constr type 1
# 3                         5.0                         wood frame (5)
# 4                         3.0                          constr type 3
# 5                         1.0                          constr type 1
#
#    Proposed Construction Type Proposed Construction Type Description  \
# 0                         NaN                                    NaN
# 2                         1.0                          constr type 1
# 3                         5.0                         wood frame (5)
# 4                         NaN                                    NaN
# 5                         1.0                          constr type 1
#
#    Supervisor District  Issued_month  Issued_weekday  Expiration_month  \
# 0                  3.0          11.0             0.0              11.0
# 2                  3.0           NaN             NaN               NaN
# 3                  3.0           7.0             1.0               7.0
# 4                  6.0          12.0             4.0              12.0
# 5                 10.0           7.0             3.0               7.0
#
#    Expiration_weekday
# 0                 3.0
# 2                 NaN
# 3                 4.0
# 4                 5.0
# 5                 6.0

# %%
plt.title('Issued and Expiration month of permits')
plt.hist([building_df['Issued_month'],building_df['Expiration_month']], stacked = True)
plt.legend(['Issued month', 'Expiration month']);

# %% [markdown]
# >It is clear that most of the permits issues and expires on **first month** of the year then forthcoming with end of the year.
#
# >Now, i will take look over weekday data and then come for an conclusion.

# %%
plt.title('Issued and Expiration weekday of permits')
plt.hist([building_df['Issued_weekday'], building_df['Expiration_weekday']], 
        stacked = False)
plt.legend(['Issued weekday', 'Expiration weekday']);

# %% [markdown]
# >Most of the issued permits were on **Tuesday** and most of the expired permits were **Friday**.

# %% [markdown]
# >From the analyzation it is clear that the best month for applying new permit is **April** since least number of permits issued and expired in this month, hence there will less crowd in the office at that time of period.
#
# >And in April month **Mondays** are the best because there are least permits that are issued on that day.
#
# **Note:-** 5th and 6th day are not taken in account because Saturdays and Sundays are off for government offices.

# %% [markdown]
# ### Buildings Street Address
#
# >I will now take look over the addresses of the buildings in which street they reside.

# %%
street = building_df['Street Suffix'].value_counts().head(5)
street
# Out:
# St    95725
# Av    32343
# Wy     2731
# Bl     2726
# Dr     2724
# Name: Street Suffix, dtype: int64

# %%
plt.plot(street.index, street, 'or' )
plt.title('Number of building in streets');

# %% [markdown]
# >There is too much difference in building counting from some certain streets. **St** have the most buildings that have acquired permits which shows that development of buildings are most in this part of the city.

# %% [markdown]
# ### Supervisor District
#
# >From this we can get the information about the building's permit record that is there to every  supervisor district and easily know the changes that were mostly taking under which district

# %%
district = building_df['Supervisor District'].value_counts()

# %%
plt.title('number buildings under Supervisor District')
plt.bar(district.index, district);

# %% [markdown]
# >Hence, it is clear that **3.0** district supervisor have the most buildings that were going through changes.

# %% [markdown]
# ## Inferences and Conclusion
#
# >In the dataset the excess amount of data is provided with alot of null values and wrong values and still get valuable information after data cleaning and sorting the data such as:
# >>* Maximum permit type that is acquired by buildings.
# >>* Correlation between different variables to know if any factor is dependable and can be perdictable.
# >>* Best time to reach office and chances to get file issued.
# >>* Most development that take place in particular area.
# >>* Number that come under each Supervisor district.

# %% [markdown]
# ## References and Future Work
# >Check out the following resources to know more about the dataset and tools used in this notebook:
# >>* For more information about permit issuing:
# https://www.thespruce.com/what-is-a-building-permit-1398344
# >>* Pandas user guide: https://pandas.pydata.org/docs/user_guide/index.html
# (https://pandas.pydata.org/docs/user_guide/index.html)
# >>* Matplotlib user guide: https://matplotlib.org/3.3.1/users/index.html
# (https://matplotlib.org/3.3.1/users/index.html)
# >>* Seaborn user guide & tutorial: https://seaborn.pydata.org/tutorial.html
# (https://seaborn.pydata.org/tutorial.html)
# >>* Opendatasets Python library: https://github.com/JovianML/opendatasets
# (https://github.com/JovianML/opendatasets
# >>* Project uploaded link:
# https://github.com/Jappreet-Singh/My-projects
